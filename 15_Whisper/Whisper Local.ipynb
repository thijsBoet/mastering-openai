# %%
import whisper

# %%
model = whisper.load_model("base")

# %%
res = model.transcribe("./audio/italian_news.wav")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
res
# Out:
# {'text': " Intra cresce l'allarme per il virus in China, in Italia, soltanto la scorsa settimana, sono stati segnalati quasi 500.000 casi di influenza stagionale, che a metà gennaio sta dunque raggiungendo il suo picco, come era stato previsto dal Ministero della Salute. Finora, gli italiani colpiti sono quasi tre milioni.",
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 5.34,
#    'text': " Intra cresce l'allarme per il virus in China, in Italia, soltanto la scorsa settimana,",
#    'tokens': [50364,
#     5681,
#     424,
#     20964,
#     384,
#     287,
#     6,
#     336,
#     35890,
#     680,
#     1930,
#     5752,
#     294,
#     3533,
#     11,
#     294,
#     41355,
#     11,
#     1404,
#     83,
#     5857,
#     635,
#     795,
#     38822,
#     5584,
#     36497,
#     11,
#     50631],
#    'temperature': 0.0,
#    'avg_logprob': -0.31392099380493166,
#    'compression_ratio': 1.4604651162790698,
# ...
